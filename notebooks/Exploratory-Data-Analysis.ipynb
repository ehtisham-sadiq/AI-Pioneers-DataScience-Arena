# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import scipy.stats as stats

# %% [markdown]
# ## Types of Analysis
#
# - **Uni-varite Analysis**
# - **Bi-Varite Analysis**
# - **Multi-variate Analysis**

# %% [markdown]
# ### Univariate Analysis:
#
# - **Numerical Columns:** Histogram, Box Plot, Density Plot, Violin Plot, Q-Q Plot, Scatter Plot Matrix
# - **Categorical Columns:** Bar Plot, Pie Chart, Donut Chart, Treemap

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(df['total_bill']) # returns distribution
#sns.boxplot()
#sns.kdeplot()
#sns.violinplot()
#stats.probplot(dist='norm', plot=plt)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
#outliers detection and min, max, IQR range
sns.boxplot(df['total_bill'], data=df);
# Out:
# /home/dell/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.kdeplot(df['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(df['total_bill'])
# Out:
# /home/dell/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
df.total_bill.mean()
# Out:
# 19.78594262295082

# %%
#df.describe()

# %%
sns.violinplot(df['total_bill'])
# Out:
# /home/dell/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

# Generate some random data
# data = np.random.normal(size=1000)

# Generate the Q-Q plot
stats.probplot(df.total_bill, dist="norm", plot=plt)

# Set the plot title and axis labels
plt.title('Q-Q Plot of Random Data')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
# Out:
# Text(0, 0.5, 'Sample Quantiles')

# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

# Generate some random data
# data = np.random.normal(size=1000)

# Generate the Q-Q plot
stats.probplot(df.tip, dist="norm", plot=plt)

# Set the plot title and axis labels
plt.title('Q-Q Plot of Random Data')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
# Out:
# Text(0, 0.5, 'Sample Quantiles')

# %%
#sns.boxplot(df.tip)
sns.distplot(df.tip)
# Out:
# /home/dell/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.pairplot(df);

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#sns.barplot(x='size', data=df);

# %%
sns.countplot(df['size']);
# Out:
# /home/dell/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.pie(x=values, labels=labels, autopct='%.2f');

# %%
labels = df['size'].value_counts().index.to_numpy()

# %%
values = df['size'].value_counts().values

# %% [markdown]
# ## Bivariate Analysis:
#
# - **Numerical-Numerical Columns:** Scatter Plot, Line Plot, Heat Map
#
#
# - **Numerical-Categorical Columns:** Box Plot, Violin Plot, Swarm Plot, Strip Plot, Point Plot, Bar Plot, Grouped Bar Plot
#
#
# - **Categorical-Categorical Columns:** Stacked Bar Plot, Grouped Bar Plot, Heat Map, Clustered Bar Plot

# %%
sns.scatterplot(x='tip', y='total_bill', data=df);

# %%
sns.lineplot(x='total_bill', y='tip', data=df);

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.boxplot(x='sex', y= 'total_bill', data=df);

# %%
sns.violinplot(x='sex', y= 'total_bill', data=df);

# %%
sns.violinplot(y='sex', x= 'total_bill', data=df);

# %%
sns.swarmplot(x='sex', y= 'total_bill', data=df);

# %%
sns.stripplot(x='sex', y= 'total_bill', data=df);

# %%
sns.pointplot(x='sex', y= 'total_bill', data=df);

# %%
df.groupby('sex')['total_bill'].mean()
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
sns.barplot(x='sex', y= 'tip',hue='smoker',, data=df);

# %%
df.groupby(['sex','smoker'])['tip'].mean()
# Out:
# sex     smoker
# Male    Yes       3.051167
#         No        3.113402
# Female  Yes       2.931515
#         No        2.773519
# Name: tip, dtype: float64

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Multivariate Analysis:
#
# - **Numerical Columns:** Pair Plot, Scatter Plot Matrix, Heat Map
# - **Categorical Columns:** Stacked Bar Plot, Grouped Bar Plot, Heat Map, Clustered Bar Plot
# - **Numerical-Categorical Columns:** Box Plot, Violin Plot, Swarm Plot, Strip Plot, Point Plot, Bar Plot, Grouped Bar Plot
# - **Numerical-Numerical Columns:** Scatter Plot, Line Plot, Heat Map
